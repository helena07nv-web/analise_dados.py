# %% [markdown]
# <a href="https://colab.research.google.com/github/helena07nv-web/analise_dados.py/blob/main/C%C3%B3pia_de_untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

dados = {
    'Produto': ['Arroz', 'Feijão', 'Macarrão', 'Óleo', 'Açúcar'],
    'Preço': [20.0, np.nan, 8.5, np.nan, 5.0],
    'Quantidade': [2, 3, 5, 1, 4]
}

df = pd.DataFrame(dados)
print("DataFrame original:")
print(df)
# Out:
# DataFrame original:
#     Produto  Preço  Quantidade
# 0     Arroz   20.0           2
# 1    Feijão    NaN           3
# 2  Macarrão    8.5           5
# 3      Óleo    NaN           1
# 4    Açúcar    5.0           4
